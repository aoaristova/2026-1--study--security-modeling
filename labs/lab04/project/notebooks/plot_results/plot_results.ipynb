# %%
using DrWatson
@quickactivate "project"
using Plots, DataFrames, Statistics
include(srcdir("simulation.jl"))
results = load_results()
# Out:
# Precompiling Plots
#   ✓ OpenSSL_jll
#   ✓ Pixman_jll
#   ✓ LERC_jll
#   ✓ libpng_jll
#   ✓ XZ_jll
#   ✓ libaom_jll
#   ✓ JpegTurbo_jll
#   ✓ Expat_jll
#   ✓ Libuuid_jll
#   ✓ FreeType2_jll
#   ✓ Libtiff_jll
#   ✓ Ghostscript_jll
#   ✓ OpenSSL
#   ✓ Fontconfig_jll
#   ✓ Cairo_jll
#   ✓ Qt6Base_jll
#   ✓ Latexify
#   ✓ HarfBuzz_jll
#   ✓ Qt6ShaderTools_jll
#   ✓ Qt6Svg_jll
#   ✓ libass_jll
#   ✓ Pango_jll
#   ✓ GLFW_jll
#   ✓ Qt6Declarative_jll
#   ✓ FFMPEG_jll
#   ✓ Latexify → DataFramesExt
#   ✓ FFMPEG
#   ✓ GR_jll
#   ✓ Latexify → SparseArraysExt
#   ✓ HTTP
#   ✓ GR
#   ✓ GR → IJuliaExt
#   ✓ Plots
#   33 dependencies successfully precompiled in 87 seconds. 148 already precompiled.
# Precompiling FileIOExt
#   ✓ FileIO → HTTPExt
#   ✓ Latexify → DataFramesExt
#   ✓ Plots → FileIOExt
#   3 dependencies successfully precompiled in 8 seconds. 181 already precompiled.
# Precompiling IJuliaExt
#   ✓ Plots → GeometryBasicsExt
#   ✓ Plots → IJuliaExt
#   2 dependencies successfully precompiled in 10 seconds. 192 already precompiled.
# 81×11 DataFrame
#  Row │ V1       p_1       V2       q_1       p_2       c_a      q_2       UA   ⋯
#      │ Float64  Float64   Float64  Float64   Float64   Float64  Float64   Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     5.0  0.5           5.0  0.5       0.5           0.0  0.5        2.5 ⋯
#    2 │     5.0  0.5           5.0  0.5       0.5           0.0  0.5        2.5
#    3 │     5.0  0.5           5.0  0.5       0.5           0.0  0.5        2.5
#    4 │     5.0  0.5           5.0  0.5       0.5           1.0  0.5        1.5
#    5 │     5.0  0.5           5.0  0.5       0.5           1.0  0.5        1.5 ⋯
#    6 │     5.0  0.5           5.0  0.5       0.5           1.0  0.5        1.5
#    7 │     5.0  0.5           5.0  0.5       0.5           3.0  0.5       -0.5
#    8 │     5.0  0.5           5.0  0.5       0.5           3.0  0.5       -0.5
#    9 │     5.0  0.5           5.0  0.5       0.5           3.0  0.5       -0.5 ⋯
#   10 │     5.0  0.666667     10.0  0.333333  0.333333      0.0  0.666667   3.3
#   11 │     5.0  0.666667     10.0  0.333333  0.333333      0.0  0.666667   3.3
#   ⋮  │    ⋮        ⋮         ⋮        ⋮         ⋮         ⋮        ⋮         ⋮ ⋱
#   72 │    15.0  0.4          10.0  0.6       0.6           3.0  0.4        3.0
#   73 │    15.0  0.5          15.0  0.5       0.5           0.0  0.5        7.5 ⋯
#   74 │    15.0  0.5          15.0  0.5       0.5           0.0  0.5        7.5
#   75 │    15.0  0.5          15.0  0.5       0.5           0.0  0.5        7.5
#   76 │    15.0  0.5          15.0  0.5       0.5           1.0  0.5        6.5
#   77 │    15.0  0.5          15.0  0.5       0.5           1.0  0.5        6.5 ⋯
#   78 │    15.0  0.5          15.0  0.5       0.5           1.0  0.5        6.5
#   79 │    15.0  0.5          15.0  0.5       0.5           3.0  0.5        4.5
#   80 │    15.0  0.5          15.0  0.5       0.5           3.0  0.5        4.5
#   81 │    15.0  0.5          15.0  0.5       0.5           3.0  0.5        4.5 ⋯
#                                                    4 columns and 60 rows omitted

# %% [markdown]
# График: p1 от V1/V2 при фиксированных затратах

# %%
filtered = results[(results.c_a .== 1.0) .& (results.c_d .== 1.0), :]
ratio = filtered.V1 ./ filtered.V2
scatter(
    ratio,
    filtered.p_1,
    group = filtered.type,
    xlabel = "V1 / V2",
    ylabel = "p1 (вероятность атаки на актив 1)",
    title = "Стратегия Нападающего (c_a=1, c_d=1)",
    legend = :topright,
)
savefig(plotsdir("p1_vs_ratio.png"))
# Out:
# "c:\\Users\\arist\\Github\\2026-1--study--security-modeling\\labs\\lab04\\project\\plots\\p1_vs_ratio.png"

# %% [markdown]
# Тепловая карта выигрыша Нападающего

# %%
grp = groupby(filtered, [:V1, :V2])
summ = combine(grp, :UA => mean => :UA_mean)
heatmap(
    sort(unique(summ.V1)),
    sort(unique(summ.V2)),
    (x, y) -> summ[(summ.V1 .== x) .& (summ.V2 .== y), :UA_mean][1],
    xlabel = "V1",
    ylabel = "V2",
    title = "Средний выигрыш Нападающего",
)
savefig(plotsdir("heatmap_UA.png"))
# Out:
# "c:\\Users\\arist\\Github\\2026-1--study--security-modeling\\labs\\lab04\\project\\plots\\heatmap_UA.png"
